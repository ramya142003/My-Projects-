# %% [markdown]
# # Problem Statement

# %% [markdown]
# The film industry has undergone significant transformations over the past century, with changes in technology, storytelling, and audience preferences shaping the way movies are made and consumed. To gain valuable insights into this dynamic industry, we have access to a comprehensive movie dataset spanning from 1920 to 2016. This dataset includes information on thousands of movies, including details such as release dates, genres, directors, budget, titles, actors, box office revenue, and critical ratings.
#
# The primary objective of this analysis is to uncover key trends, patterns, and factors that have influenced the world of cinema over the past century, including factors affecting a movie's success, changing audience preferences, and the impact of technological advancements on the industry.
#
# Ultimately, this project aims to provide actionable recommendations for filmmakers, studios, and investors to make informed decisions in the modern film landscape.

# %%
# Import Libraries

import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.simplefilter(action="ignore",category=FutureWarning)

# %% [markdown]
# ## Reading the dataset:

# %%
df=pd.read_csv("movie_dataset.csv")
df
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ## Basic Operations :
#
# - shape
# - dtypes
# - columns
# - unique
# - nunique
# - count
# - value_count
# - info
# - describe

# %%
df.shape
# Out:
# (4803, 24)

# %%
df.head(10)
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
# 5      5  258000000                  Fantasy Action Adventure
# 6      6  260000000                          Animation Family
# 7      7  280000000          Action Adventure Science Fiction
# 8      8  250000000                  Adventure Fantasy Family
# 9      9  250000000                  Action Adventure Fantasy
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
df.tail(10)
# Out:
#       index  budget                          genres  \
# 4793   4793       0                           Drama
# 4794   4794       0          Thriller Horror Comedy
# 4795   4795       0                           Drama
# 4796   4796    7000  Science Fiction Drama Thriller
# 4797   4797       0                Foreign Thriller
# 4798   4798  220000           Action Crime Thriller
# 4799   4799    9000                  Comedy Romance
# 4800   4800       0   Comedy Drama Romance TV Movie
# 4801   4801       0                             NaN
# 4802   4802       0                     Documentary
#
#                                                homepage      id  \
# 4793                                                NaN  182291
# 4794                                                NaN  286939
# 4795                                                NaN  124606
# 4796                         http://www.primermovie.com   14337
# 4797                                                NaN   67238
# ...

# %%
df.dtypes
# Out:
# index                     int64
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# cast                     object
# crew                     object
# director                 object
# dtype: object

# %%
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director'],
#       dtype='object')

# %%
df['title'].unique()
# Out:
# array(['Avatar', "Pirates of the Caribbean: At World's End", 'Spectre',
#        ..., 'Signed, Sealed, Delivered', 'Shanghai Calling',
#        'My Date with Drew'], dtype=object)

# %%
df.nunique()
# Out:
# index                   4803
# budget                   436
# genres                  1168
# homepage                1691
# id                      4803
# keywords                4219
# original_language         37
# original_title          4801
# overview                4800
# popularity              4802
# production_companies    3697
# production_countries     469
# release_date            3280
# revenue                 3297
# runtime                  156
# spoken_languages         544
# status                     3
# tagline                 3944
# title                   4800
# vote_average              71
# vote_count              1609
# cast                    4741
# crew                    4776
# director                2349
# dtype: int64

# %%
df.count()
# Out:
# index                   4803
# budget                  4803
# genres                  4775
# homepage                1712
# id                      4803
# keywords                4391
# original_language       4803
# original_title          4803
# overview                4800
# popularity              4803
# production_companies    4803
# production_countries    4803
# release_date            4802
# revenue                 4803
# runtime                 4801
# spoken_languages        4803
# status                  4803
# tagline                 3959
# title                   4803
# vote_average            4803
# vote_count              4803
# cast                    4760
# crew                    4803
# director                4773
# dtype: int64

# %%
df['genres'].value_counts()
# Out:
# Drama                                     370
# Comedy                                    282
# Drama Romance                             164
# Comedy Romance                            144
# Comedy Drama                              142
#                                          ...
# Adventure Comedy Crime Science Fiction      1
# Action Comedy Family Adventure              1
# Drama Adventure Western                     1
# Adventure Fantasy Action Romance            1
# Comedy Drama Romance TV Movie               1
# Name: genres, Length: 1168, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 4803 non-null   int64
#  1   budget                4803 non-null   int64
#  2   genres                4775 non-null   object
#  3   homepage              1712 non-null   object
#  4   id                    4803 non-null   int64
#  5   keywords              4391 non-null   object
#  6   original_language     4803 non-null   object
#  7   original_title        4803 non-null   object
#  8   overview              4800 non-null   object
#  9   popularity            4803 non-null   float64
#  10  production_companies  4803 non-null   object
#  11  production_countries  4803 non-null   object
#  12  release_date          4802 non-null   object
#  13  revenue               4803 non-null   int64
#  14  runtime               4801 non-null   float64
# ...

# %%
df.describe()
# Out:
#              index        budget             id   popularity       revenue  \
# count  4803.000000  4.803000e+03    4803.000000  4803.000000  4.803000e+03
# mean   2401.000000  2.904504e+07   57165.484281    21.492301  8.226064e+07
# std    1386.651002  4.072239e+07   88694.614033    31.816650  1.628571e+08
# min       0.000000  0.000000e+00       5.000000     0.000000  0.000000e+00
# 25%    1200.500000  7.900000e+05    9014.500000     4.668070  0.000000e+00
# 50%    2401.000000  1.500000e+07   14629.000000    12.921594  1.917000e+07
# 75%    3601.500000  4.000000e+07   58610.500000    28.313505  9.291719e+07
# max    4802.000000  3.800000e+08  459488.000000   875.581305  2.787965e+09
#
#            runtime  vote_average    vote_count
# count  4801.000000   4803.000000   4803.000000
# mean    106.875859      6.092172    690.217989
# std      22.611935      1.194612   1234.585891
# min       0.000000      0.000000      0.000000
# 25%      94.000000      5.600000     54.000000
# ...

# %%
df.describe(include="all")
# Out:
#               index        budget genres                           homepage  \
# count   4803.000000  4.803000e+03   4775                               1712
# unique          NaN           NaN   1168                               1691
# top             NaN           NaN  Drama  http://www.missionimpossible.com/
# freq            NaN           NaN    370                                  4
# mean    2401.000000  2.904504e+07    NaN                                NaN
# std     1386.651002  4.072239e+07    NaN                                NaN
# min        0.000000  0.000000e+00    NaN                                NaN
# 25%     1200.500000  7.900000e+05    NaN                                NaN
# 50%     2401.000000  1.500000e+07    NaN                                NaN
# 75%     3601.500000  4.000000e+07    NaN                                NaN
# max     4802.000000  3.800000e+08    NaN                                NaN
#
# ...

# %% [markdown]
# ## Data Cleaning:

# %%
# Check if there any missing values are in dataset or not

df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# index                      0
# budget                     0
# genres                    28
# homepage                3091
# id                         0
# keywords                 412
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# cast                      43
# crew                       0
# director                  30
# dtype: int64

# %%
# Fill missing values in specific columns
median_runtime = df['runtime'].median()
df['runtime'].fillna(median_runtime, inplace=True)

# %%
df['director'].fillna('Unknown', inplace=True)

# %%
# Drop rows with missing dates
df.dropna(subset=['release_date'], inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# index                   0
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# cast                    0
# crew                    0
# director                0
# dtype: int64

# %%
# check if there any duplicates

df.duplicated().any()
# Out:
# False

# %% [markdown]
# ## Data Filtering:

# %%
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director'],
#       dtype='object')

# %%
# # Convert columns to different data types

df[['popularity' ,'runtime']].astype(int)
# Out:
#       popularity  runtime
# 0            150      162
# 1            139      169
# 2            107      148
# 3            112      165
# 4             43      132
# ...          ...      ...
# 4772           1       89
# 4773          19       92
# 4781           0       90
# 4791           0       84
# 4796          23       77
#
# [1432 rows x 2 columns]

# %%
# convert datatype of release_date

df['release_date']=pd.to_datetime(df['release_date'])
df['release_date']
# Out:
# 0      2009-12-10
# 1      2007-05-19
# 2      2015-10-26
# 3      2012-07-16
# 4      2012-03-07
#           ...
# 4772   2009-09-01
# 4773   1994-09-13
# 4781   2013-02-14
# 4791   2007-01-01
# 4796   2004-10-08
# Name: release_date, Length: 1432, dtype: datetime64[ns]

# %%
# Filter year and month From release data

df['release_ year']=df['release_date'].dt.year

df['release_month'] = df['release_date'].dt.month

df[['release_date','release_ year','release_month']]
# Out:
#      release_date  release_ year  release_month
# 0      2009-12-10           2009             12
# 1      2007-05-19           2007              5
# 2      2015-10-26           2015             10
# 3      2012-07-16           2012              7
# 4      2012-03-07           2012              3
# ...           ...            ...            ...
# 4772   2009-09-01           2009              9
# 4773   1994-09-13           1994              9
# 4781   2013-02-14           2013              2
# 4791   2007-01-01           2007              1
# 4796   2004-10-08           2004             10
#
# [1432 rows x 3 columns]

# %%
# Display title of the movie having runtime >=180 minutes?

df[df['runtime']>=180]['title']
# Out:
# 25                                            Titanic
# 298                           The Wolf of Wall Street
# 329     The Lord of the Rings: The Return of the King
# 690                                    The Green Mile
# 1333                                         Magnolia
# 1818                                 Schindler's List
# Name: title, dtype: object

# %%
# Display Top 20 genres in the dataset

top_20_genres = df['genres'].value_counts().head(20).index
filtered_data = df[df['genres'].isin(top_20_genres)]
filtered_data
# Out:
#       index     budget                            genres  \
# 6         6  260000000                  Animation Family
# 26       26  250000000  Adventure Action Science Fiction
# 39       39  170000000  Adventure Action Science Fiction
# 57       57  180000000                  Animation Family
# 79       79  200000000  Adventure Action Science Fiction
# ...     ...        ...                               ...
# 4746   4746          0                             Drama
# 4765   4765          0                            Horror
# 4773   4773      27000                            Comedy
# 4781   4781      22000                    Comedy Romance
# 4791   4791         13                            Horror
#
#                                                homepage      id  \
# 6          http://disney.go.com/disneypictures/tangled/   38757
# 26             http://marvel.com/captainamericapremiere  271110
# 39                           http://disney.go.com/tron/   20526
# ...

# %%
# Get the top 5 highest and lowest revenue movies
lowest_revenue_movies = df.nsmallest(5, 'revenue')
lowest_revenue_movies
# Out:
#      index     budget                         genres  \
# 135    135  150000000          Drama Horror Thriller
# 406    406          0  Drama Animation Family Comedy
# 433    433   84000000   Action Comedy Crime Thriller
# 719    719   60000000              Music Documentary
# 757    757          0                  Drama Romance
#
#                                        homepage      id  \
# 135             http://www.thewolfmanmovie.com/    7978
# 406             http://www.arthurchristmas.com/   51052
# 433                    http://red-themovie.com/  146216
# 719               http://www.thisisit-movie.com   13576
# 757  http://troublewiththecurve.warnerbros.com/   87825
#
#                                               keywords original_language  \
# 135  father son relationship victorian england rema...                en
# 406  holiday santa claus duringcreditsstinger woman...                en
# 433                paris london england cia russia mi6                en
# ...

# %%
top_revenue_movies = df.nlargest(5, 'revenue')
top_revenue_movies
# Out:
#     index     budget                                     genres  \
# 0       0  237000000   Action Adventure Fantasy Science Fiction
# 25     25  200000000                     Drama Romance Thriller
# 16     16  220000000           Science Fiction Action Adventure
# 28     28  150000000  Action Adventure Science Fiction Thriller
# 44     44  190000000                                     Action
#
#                              homepage      id  \
# 0         http://www.avatarmovie.com/   19995
# 25        http://www.titanicmovie.com     597
# 16  http://marvel.com/avengers_movie/   24428
# 28      http://www.jurassicworld.com/  135397
# 44           http://www.furious7.com/  168259
#
#                                              keywords original_language  \
# 0   culture clash future space war space colony so...                en
# 25               shipwreck iceberg ship panic titanic                en
# 16  new york shield marvel comic superhero based o...                en
# ...

# %%
# Display only list of 5 movies with specific director named as 'Christopher Nolan'

movies_by_director = df[df['director'] == 'Christopher Nolan']
movies_by_director.head(5)
movie_titles = movies_by_director['title'].tolist()
for title in movie_titles:
    print(title)
# Out:
# The Dark Knight Rises
# The Dark Knight
# Interstellar
# Inception
# Batman Begins
# The Prestige
# Memento

# %%
# Display top 10 movies that released after 2010 ?

movies_after_2010 = df[df['release_date'] >= '2010-01-01']
movies_after_2010.head(10)
# Out:
#     index     budget                                    genres  \
# 2       2  245000000                    Action Adventure Crime
# 3       3  250000000               Action Crime Drama Thriller
# 4       4  260000000          Action Adventure Science Fiction
# 6       6  260000000                          Animation Family
# 7       7  280000000          Action Adventure Science Fiction
# 9       9  250000000                  Action Adventure Fantasy
# 13     13  255000000                  Action Adventure Western
# 14     14  225000000  Action Adventure Fantasy Science Fiction
# 16     16  220000000          Science Fiction Action Adventure
# 17     17  380000000                  Adventure Action Fantasy
#
#                                              homepage      id  \
# 2         http://www.sonypictures.com/movies/spectre/  206647
# 3                  http://www.thedarkknightrises.com/   49026
# 4                http://movies.disney.com/john-carter   49529
# ...

# %%
# Which Movie Has The Highest Or Lowest Profit?

df['Profit'] = df['revenue'] - df['budget']
def find_minmax(x):
    
    min_index = df[x].idxmin()
    high_index = df[x].idxmax()
    high = pd.DataFrame(df.loc[high_index,:])
    low = pd.DataFrame(df.loc[min_index,:])
    print("Movie Which Has Highest "+ x + " : ",df['original_title'][high_index])
    print("Movie Which Has Lowest "+ x + "  : ",df['original_title'][min_index])
    return pd.concat([high,low],axis = 1)

find_minmax('Profit')
# Out:
# Movie Which Has Highest Profit :  Avatar
# Movie Which Has Lowest Profit  :  The Lone Ranger
#                                                                      0   \
# index                                                                 0
# budget                                                        237000000
# genres                         Action Adventure Fantasy Science Fiction
# homepage                                    http://www.avatarmovie.com/
# id                                                                19995
# keywords              culture clash future space war space colony so...
# original_language                                                    en
# original_title                                                   Avatar
# overview              In the 22nd century, a paraplegic Marine is di...
# popularity                                                   150.437577
# production_companies  [{"name": "Ingenious Film Partners", "id": 289...
# ...

# %%
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director',
#        'release_ year', 'release_month', 'Profit'],
#       dtype='object')

# %%
# Filter the DataFrame to genres == Action, production_countries== US and runtimeMinutes is less than 240
df1 = df[(df['genres']=='Action') & (df['production_countries']=='US') & (df['runtime']<240)]
df1
# Out:
# Empty DataFrame
# Columns: [index, budget, genres, homepage, id, keywords, original_language, original_title, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, vote_average, vote_count, cast, crew, director, release_ year, release_month, Profit]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# ## Grouping:

# %%
# Which year has the highest release of movies?

data=df.groupby('release_ year').count()['id']
print(data.tail(20))
# Out:
# release_ year
# 1997     10
# 1998     12
# 1999     24
# 2000     19
# 2001     19
# 2002     35
# 2003     30
# 2004     44
# 2005     55
# 2006     78
# 2007     90
# 2008    103
# 2009    131
# 2010    138
# 2011    155
# 2012     97
# 2013     82
# 2014     68
# 2015     87
# 2016     64
# Name: id, dtype: int64

# %%
# Top 10 Average Runtime Of Movies From Year To Year?

df1=df.groupby('release_ year').mean()['runtime'].head(10)
df1
# Out:
# release_ year
# 1937     83.0
# 1939    102.0
# 1940    124.0
# 1942     70.0
# 1962    110.0
# 1963    115.0
# 1964     99.0
# 1965    130.0
# 1966    161.0
# 1967    117.0
# Name: runtime, dtype: float64

# %%
#  Which length movies most liked by the audiences according to their popularity?

df.groupby('runtime')['popularity'].mean().value_counts()
# Out:
# 0.674398      1
# 48.842713     1
# 91.086923     1
# 100.895542    1
# 42.051565     1
#              ..
# 28.109935     1
# 38.009809     1
# 25.674326     1
# 27.554878     1
# 123.630332    1
# Name: popularity, Length: 106, dtype: int64

# %%
# The Profit Rate for last 5 years?

df.groupby('release_ year')['Profit'].mean().tail()
# Out:
# release_ year
# 2012    1.337318e+08
# 2013    1.298617e+08
# 2014    1.831558e+08
# 2015    1.623366e+08
# 2016    1.321102e+08
# Name: Profit, dtype: float64

# %%
# average voting for last 10 years?

df.groupby('release_ year')['vote_average'].mean().tail(10)
# Out:
# release_ year
# 2007    6.394444
# 2008    6.168932
# 2009    6.219084
# 2010    6.214493
# 2011    6.137419
# 2012    6.169072
# 2013    6.369512
# 2014    6.391176
# 2015    6.248276
# 2016    6.018750
# Name: vote_average, dtype: float64

# %%
#  the average revenue for last 5 years

df.groupby('release_ year')['revenue'].mean().tail()
# Out:
# release_ year
# 2012    1.909965e+08
# 2013    1.881741e+08
# 2014    2.504389e+08
# 2015    2.207687e+08
# 2016    1.928837e+08
# Name: revenue, dtype: float64

# %%
# Find the average rating for each director 
df.groupby('director')['vote_average'].mean()
# Out:
# director
# Adam Brooks                   6.700000
# Adam Green                    5.700000
# Adam McKay                    6.533333
# Adam Shankman                 6.450000
# Agnieszka Wojtowicz-Vosloo    5.400000
#                                 ...
# Yvette Kaplan                 4.600000
# Zack Snyder                   6.485714
# Zal Batmanglij                6.500000
# Zhang Yimou                   6.600000
# \u00c9mile Gaudreault         5.600000
# Name: vote_average, Length: 875, dtype: float64

# %%
data=df.groupby('release_ year').count()['id']
print(data.tail())
# Out:
# release_ year
# 2012    97
# 2013    82
# 2014    68
# 2015    87
# 2016    64
# Name: id, dtype: int64

# %%
g=df.groupby('genres')
g

# %%
g.ngroups
# Out:
# 535

# %%
g.get_group("Action").head(5)
# Out:
#       index     budget  genres                               homepage      id  \
# 44       44  190000000  Action               http://www.furious7.com/  168259
# 708     708   61000000  Action            http://mazerunnermovies.com  294254
# 750     750   60000000  Action       http://www.stateofplaymovie.net/   16995
# 1104   1104   40000000  Action  http://www.thebountyhunter-movie.net/   27573
# 1398   1398   35000000  Action        http://www.maxpaynethemovie.com   13051
#
#                                                keywords original_language  \
# 44                  car race speed revenge suspense car                en
# 708   based on novel resistance maze post-apocalypti...                en
# 750   corruption assassination detective journalist ...                en
# 1104      bounty hunter ex-husband ex-wife relationship                en
# 1398   assassin based on video game aftercreditsstinger                en
#
#                       original_title  \
# ...

# %% [markdown]
# ## Sorting:

# %%
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director',
#        'release_ year', 'release_month', 'Profit'],
#       dtype='object')

# %%
# Which Year Has The Highest Profit Rate for last 5 years?

df.groupby('release_ year')['Profit'].mean().sort_values( ascending=False).head()
# Out:
# release_ year
# 1977    4.679183e+08
# 1993    3.899938e+08
# 1973    2.940420e+08
# 1997    2.703145e+08
# 1942    2.665892e+08
# Name: Profit, dtype: float64

# %%
# In which year there was the highest average voting for last 10 years?

df.groupby('release_ year')['vote_average'].mean().tail(10).sort_values( ascending=True)
# Out:
# release_ year
# 2016    6.018750
# 2011    6.137419
# 2008    6.168932
# 2012    6.169072
# 2010    6.214493
# 2009    6.219084
# 2015    6.248276
# 2013    6.369512
# 2014    6.391176
# 2007    6.394444
# Name: vote_average, dtype: float64

# %%
# In which year there was the highest average revenue for last 5 years

df.groupby('release_ year')['revenue'].mean().sort_values( ascending=True).head()
# Out:
# release_ year
# 1966    6.000000e+06
# 1988    6.948317e+06
# 1991    7.434726e+06
# 1986    1.100000e+07
# 1939    3.375497e+07
# Name: revenue, dtype: float64

# %%
# top 10 movies which earn highest profit.

top_10_profit_movies = df.sort_values(by='Profit', ascending=False).head(10)
top_10_profit_movies_df = top_10_profit_movies[['title', 'Profit']]
print(top_10_profit_movies_df)
# Out:
#                                              title      Profit
# 0                                           Avatar  2550965087
# 25                                         Titanic  1645034188
# 28                                  Jurassic World  1363528810
# 44                                       Furious 7  1316249360
# 16                                    The Avengers  1299557910
# 7                          Avengers: Age of Ultron  1125403694
# 124                                         Frozen  1124219009
# 546                                        Minions  1082730962
# 329  The Lord of the Rings: The Return of the King  1024888979
# 31                                      Iron Man 3  1015439994

# %%
# What are the top 10 highest-grossing movies?

top_10_highest_grossing_movies = df.sort_values(by='revenue', ascending=False).head(10)
top_10_highest_grossing_movies_df = top_10_highest_grossing_movies[['title', 'revenue']]
print(top_10_highest_grossing_movies_df)
# Out:
#                           title     revenue
# 0                        Avatar  2787965087
# 25                      Titanic  1845034188
# 16                 The Avengers  1519557910
# 28               Jurassic World  1513528810
# 44                    Furious 7  1506249360
# 7       Avengers: Age of Ultron  1405403694
# 124                      Frozen  1274219009
# 31                   Iron Man 3  1215439994
# 546                     Minions  1156730962
# 26   Captain America: Civil War  1153304495

# %%
# Which movies have the highest user ratings?

top_10_highest_rated_movies = df.sort_values(by='vote_average', ascending=False).head(10)
top_10_highest_rated_movies
# Out:
#       index     budget                              genres  \
# 3337   3337    6000000                         Drama Crime
# 3865   3865    3300000                               Drama
# 2294   2294   15000000  Fantasy Adventure Animation Family
# 1818   1818   22000000                   Drama History War
# 662     662   63000000                               Drama
# 1847   1847   25000000                         Drama Crime
# 65       65  185000000         Drama Action Crime Thriller
# 3057   3057   20000000                               Drama
# 690     690   60000000                 Fantasy Drama Crime
# 1990   1990   18000000    Adventure Action Science Fiction
#
#                                                homepage      id  \
# 3337                       http://www.thegodfather.com/     238
# 3865                  http://sonyclassics.com/whiplash/  244786
# 2294             http://movies.disney.com/spirited-away     129
# ...

# %%
# Which movies have the highest budgets?
top_10_highest_budget_movies = df.sort_values(by='budget', ascending=False).head(10)
top_10_highest_budget_movies_df = top_10_highest_budget_movies[['title', 'budget']]
print(top_10_highest_budget_movies_df)
# Out:
#                                           title     budget
# 17  Pirates of the Caribbean: On Stranger Tides  380000000
# 1      Pirates of the Caribbean: At World's End  300000000
# 7                       Avengers: Age of Ultron  280000000
# 4                                   John Carter  260000000
# 6                                       Tangled  260000000
# 5                                  Spider-Man 3  258000000
# 13                              The Lone Ranger  255000000
# 19    The Hobbit: The Battle of the Five Armies  250000000
# 3                         The Dark Knight Rises  250000000
# 8        Harry Potter and the Half-Blood Prince  250000000

# %%
df.sort_values('genres').head(10)
# Out:
#       index     budget                                    genres  \
# 750     750   60000000                                    Action
# 1398   1398   35000000                                    Action
# 1104   1104   40000000                                    Action
# 44       44  190000000                                    Action
# 708     708   61000000                                    Action
# 21       21  200000000                          Action Adventure
# 469     469   75000000                          Action Adventure
# 62       62  180000000                          Action Adventure
# 152     152  145000000  Action Adventure Animation Comedy Family
# 339     339   92000000         Action Adventure Animation Family
#
#                                                homepage      id  \
# 750                    http://www.stateofplaymovie.net/   16995
# 1398                    http://www.maxpaynethemovie.com   13051
# ...

# %%
popularity_desc =df.sort_values(by='popularity', ascending=False)
print(popularity_desc[['title', 'popularity']].head())
# Out:
#                        title  popularity
# 546                  Minions  875.581305
# 95              Interstellar  724.247784
# 788                 Deadpool  514.569956
# 94   Guardians of the Galaxy  481.098624
# 127       Mad Max: Fury Road  434.278564

# %% [markdown]
# ## Aggregations(min,max,mean,mode,variance):

# %%
#  Calculate aggregations for numeric columns

A =df.select_dtypes(include='number').agg(['min','max','mean','median','std','var'])
print("Aggregated Statistics for Numeric Columns:")

A
# Out:
# Aggregated Statistics for Numeric Columns:
#                index        budget            id   popularity       revenue  \
# min     0.000000e+00  0.000000e+00  1.100000e+01     0.023681  0.000000e+00
# max     4.796000e+03  3.800000e+08  3.940470e+05   875.581305  2.787965e+09
# mean    1.885148e+03  4.729039e+07  6.358191e+04    36.965023  1.603981e+08
# median  1.654500e+03  2.900000e+07  2.366850e+04    26.108374  6.807614e+07
# std     1.388674e+03  5.409809e+07  8.853175e+04    48.802540  2.440322e+08
# var     1.928415e+06  2.926604e+15  7.837871e+09  2381.687886  5.955169e+16
#
#            runtime  vote_average    vote_count  release_ year  release_month  \
# min       0.000000      0.000000  0.000000e+00    1937.000000       1.000000
# max     201.000000      8.400000  1.375200e+04    2016.000000      12.000000
# mean    109.231145      6.318156  1.373382e+03    2007.426676       6.905028
# median  106.000000      6.400000  6.660000e+02    2009.000000       7.000000
# ...

# %%
df.select_dtypes(include='number').agg([np.mean,np.median,np.amax,np.amin])
# Out:
#               index        budget             id  popularity       revenue  \
# mean    1885.148045  4.729039e+07   63581.911313   36.965023  1.603981e+08
# median  1654.500000  2.900000e+07   23668.500000   26.108374  6.807614e+07
# amax    4796.000000  3.800000e+08  394047.000000  875.581305  2.787965e+09
# amin       0.000000  0.000000e+00      11.000000    0.023681  0.000000e+00
#
#            runtime  vote_average    vote_count  release_ year  release_month  \
# mean    109.231145      6.318156   1373.381983    2007.426676       6.905028
# median  106.000000      6.400000    666.000000    2009.000000       7.000000
# amax    201.000000      8.400000  13752.000000    2016.000000      12.000000
# amin      0.000000      0.000000      0.000000    1937.000000       1.000000
#
#               Profit
# mean    1.131077e+08
# median  3.401279e+07
# amax    2.550965e+09
# amin   -1.657101e+08

# %%
mode_values=df.select_dtypes(include='number').mode().values[0]
mode_values
# Out:
# array([0.0000e+00, 0.0000e+00, 1.1000e+01, 2.3681e-02, 0.0000e+00,
#        1.0000e+02, 6.5000e+00, 6.0000e+00, 2.0110e+03, 9.0000e+00,
#        0.0000e+00])

# %% [markdown]
# ## Data Visualization:

# %%
# 1. What is the distribution of movie ratings by using histogram plot?

plt.figure(figsize=(10, 6))
sns.histplot(df['vote_average'], bins=20, kde=True ,color='Orange' )
plt.title('Distribution of Movie Ratings',fontsize=15)
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The histogram plot reveals that the majority of movies in the dataset have received relatively low ratings, with a peak in the frequency around the lower rating values. This suggests that a significant portion of the movies in the dataset has ratings clustered in the lower range.

# %%
# 2. How does the budget vary across top 20 different genres?

top_20_genres = df['genres'].value_counts().head(20).index
filtered_data = df[df['genres'].isin(top_20_genres)]
# Create a boxplot to show the budget variation across the top 20 genres
plt.figure(figsize=(14, 8))
sns.boxplot(x='genres', y='budget', data=filtered_data, palette='viridis')
plt.title('Budget Variation Across Top 20 Genres',fontsize=20)
plt.xlabel('Genres',fontsize=12)
plt.ylabel('Budget',fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The boxplot indicates that there is substantial variation in budgets across  genres. Some genres tend to have higher budgets on average, while others have lower budgets, reflecting the diversity in budget allocation within the movie industry.

# %%
#  3.Are there any trends in movie release months?

# Extract the month from the release_date column
df['release_month'] = df['release_date'].dt.month

plt.figure(figsize=(10, 6))
sns.countplot(x='release_month', data=df, palette='viridis')
plt.title('Trend of Movie Releases by Month')
plt.xlabel('Release Month')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - In september we have highest trend in release of movies.

# %%
# 4. What is the trend of movie releases over the years?

df['release_date'] = pd.to_datetime(df['release_date'])

df['release_ year'] = df['release_date'].dt.year
plt.figure(figsize=(10, 6))
sns.countplot(x='release_ year', data=df, palette='viridis')
plt.title('Trend of Movie Releases Over the Years')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The countplot illustrates Movie production has generally increased over the years, with fluctuations in the number of releases.
# - The 2000s and 2010s witnessed a significant rise in movie production, with the highest number of releases during those decades.
# - There was a relatively lower number of movie releases in earlier decades, with a gradual increase in the 1980s.

# %%
# 5: How does the revenue vary across top 20 different genres?

filtered_data = df[df['genres'].isin(top_20_genres)]
plt.figure(figsize=(12, 6))
sns.boxplot(x='genres', y='revenue', data= filtered_data, palette='coolwarm')
plt.title('Revenue Variation Across Genres')
plt.xlabel('Genre')
plt.ylabel('Revenue')
plt.xticks(rotation=90)
plt.show()

# %%
# 6. Which genres tends to have the highest budget and revenue?
plt.figure(figsize=(10, 6))
sns.scatterplot(x='budget', y='revenue', data=filtered_data, hue= "genres", palette='Set2')
plt.title('Budget vs. Revenue')
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# - The scatterplot illustrates that Action, Adventure, and Animation genres tend to have the highest budgets and in turn generate higher revenues.And some genres, like Documentary and Foreign, generally have lower budgets and lower revenues.

# %%
# 7. What are the top 15 highest-grossing movies?

top_grossing_movies = df.nlargest(15, 'revenue')
colors = sns.color_palette('viridis', len(top_grossing_movies))
# Create a bar chart with different colors for each bar
plt.figure(figsize=(12, 6))
bars = plt.barh(top_grossing_movies['title'], top_grossing_movies['revenue'], color=colors)
plt.xlabel('Revenue')
plt.ylabel('Movie Title')
plt.title('Top 10 Highest-Grossing Movies')
plt.gca().invert_yaxis()  # Invert the y-axis to display the highest-grossing movie at the top
plt.show()

# %% [markdown]
# - The bar chart provides a visual representation of the movies that have generated the highest revenues. The chart allows us to quickly identify the top-grossing movies and their respective revenue figures, with the highest-grossing movie appearing at the top.
# - Here, Avatar is the highest-grossing movie .

# %%
# 8.How many movies were released in each decade?
df['release_decade'] = (df['release_date'].dt.year // 10) * 10
decade_movie_counts = df['release_decade'].value_counts().sort_index()
decades = decade_movie_counts.index
counts = decade_movie_counts.values
# Define the width of the bars
bar_width = 1.8
# Create a bar chart to visualize the number of movies released in each decade
plt.figure(figsize=(10, 6))
colors = plt.cm.viridis(range(len(decades)))  # Using the 'viridis' color map
plt.bar(decades, counts, color=colors, width=bar_width)
plt.xlabel('Decade')
plt.ylabel('Number of Movies Released')
plt.title('Number of Movies Released in Each Decade')

# Adding custom labels for each bar
for decade, count in zip(decades, counts):
    plt.text(decade, count, str(count), ha='center', va='bottom', fontsize=10)

plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# - The bar chart revealing the following trends :
#    - Movie production has generally increased over the decades.
#    - The 2000s and 2010s have seen the highest number of movie releases.

# %%
# 9. What is the distribution of movie durations?

bins = [0, 60, 90, 120, 150, float('inf')]
labels = ['<60 min', '60-90 min', '90-120 min', '120-150 min', '150+ min']
df['duration_category'] = pd.cut(df['runtime'], bins=bins, labels=labels)
duration_counts = df['duration_category'].value_counts()

# Create an exploded pie chart
explode = (0.1, 0, 0, 0, 0)  
colors = ['orange', 'lightgreen', 'yellow', 'purple', 'pink']
plt.figure(figsize=(6, 6))
plt.pie(duration_counts, labels=duration_counts.index, autopct='%1.1f%%', startangle=140, colors=colors, explode=explode, shadow=True)
plt.title('Distribution of Movie Durations')
plt.axis('equal')  
plt.legend(title='Duration Categories', loc='lower right', labels=duration_counts.index)
plt.show()

# %% [markdown]
# - The pie chart shows that Movies with a duration of 90-120 minutes constitute the largest portion, making up 62.2% of the dataset and the second most common duration category is 120-150 minutes, accounting for 21%.

# %%
# 10. How does the rating vary by decade?
df['release_decade'] = (df['release_date'].dt.year // 10) * 10
plt.figure(figsize=(12, 6))
sns.boxplot(x='release_decade', y='vote_count', data=df, palette='husl')
plt.title('Rating Variation by Decade')
plt.xlabel('Decade')
plt.ylabel('Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - The boxplot reveals that Movies from the 1920s and 1930s tend to have a wide range of ratings, with some highly rated and some lower-rated films.
# - In more recent decades, like the 2010s, there is a tighter cluster of ratings.
# - The 1960s and 1970s showcase a mix of highly-rated and moderately-rated movies.

# %%
# 11: How has the movie production trend evolved over the years for the top 5 genres?

top5_genres =df['genres'].value_counts().nlargest(5).index
movie_data_top5 = df[df['genres'].isin(top5_genres)]
plt.figure(figsize=(12, 6))
sns.countplot(x='release_ year', hue='genres', data=movie_data_top5, palette='tab10')
plt.title('Movie Production Trend Over the Years for Top 5 Genres')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Genre')
plt.show()

# %% [markdown]
# - The countplot demonstrates that some genres have experienced variations in production from year to year, with certain years witnessing higher production counts for specific genres.

# %%
# 12. What is the distribution of movie budgets for the top 5 genres?
plt.figure(figsize=(12, 6))
sns.violinplot(x='genres', y='budget', data=movie_data_top5, palette='pastel')
plt.title('Budget Distribution for Top 5 Genres')
plt.xlabel('Genre')
plt.ylabel('Budget')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - The violin plot provides a compact summary of how budgets differ within these genres, highlighting the range and density of budget values for each genre.

# %%
# 13. How does the movie budget correlate with the movie rating?
top_10_genres = df['genres'].value_counts().head(10).index
filtered_data = df[df['genres'].isin(top_10_genres)]
plt.figure(figsize=(10, 6))
sns.scatterplot(x='budget', y='vote_count', data=filtered_data, hue='genres', palette='Set3')
plt.title('Budget vs. Rating')
plt.xlabel('Budget')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# - The scatterplot suggests that there is no strong linear relationship between budget and rating and shows that movies with varying budgets can receive a wide range of ratings across different genres.

# %%
# 14. What is the distribution of movie ratings for the top 10 genres?
top_10_genres = df['genres'].value_counts().head(10).index
filtered_data = df[df['genres'].isin(top_10_genres)]
plt.figure(figsize=(10, 5))
sns.boxplot(x='genres', y='vote_average', data=filtered_data, palette='Set1')
plt.title('Rating Distribution for Top 10 Genres')
plt.xlabel('Genre')
plt.ylabel('Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - The boxplot shows a clear summary of how ratings differ within different genres, highlighting the range, median, and potential outliers in each genre's ratings distribution.

# %%
# 15. How does the popularity vary with movie revenue?
top_10_genres = df['genres'].value_counts().head(10).index
filtered_data = df[df['genres'].isin(top_10_genres)]
plt.figure(figsize=(10, 6))
sns.scatterplot(x='revenue', y='popularity', data=filtered_data, hue='genres', palette='tab20')
plt.title('Popularity vs. Revenue')
plt.xlabel('Revenue')
plt.ylabel('popularity')
plt.show()

# %% [markdown]
# - The scatterplot shows that there is a positive correlation between popularity and revenue across these genres. It suggests that movies with higher revenues tend to be more popular.

# %%
# 16. What is the distribution of movie durations for each genre?
plt.figure(figsize=(12, 6))
sns.violinplot(x='genres', y='runtime', data=filtered_data, palette='Set2')
plt.title('Duration Distribution for Each Genre')
plt.xlabel('Genre')
plt.ylabel('Duration (minutes)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - The violin plot provides a concise visual summary of how movie runtimes differ within different genres, showcasing the range and density of duration values.

# %%
# 17. What is the relationship between budget and revenue for the top 10 genres?
plt.figure(figsize=(12, 6))
sns.scatterplot(x='budget', y='revenue', data=filtered_data, hue='genres', palette='Set3')
plt.title('Budget vs. Revenue for Top 10 Genres')
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# - The scatterplot demonstrates that the relationship between budget and revenue varies across genres. While some genres show a positive correlation between budget and revenue, others exhibit more scattered patterns, indicating that the impact of budget on revenue differs by genre.

# %%
# 18. What are top 20 the most common movie genres?

top_20_genres = df['genres'].value_counts().head(20).index

plt.figure(figsize=(10, 5))
sns.countplot(x='genres', data=df, order=top_20_genres, palette='viridis')
plt.title('Top 20 Most Common Movie Genres')
plt.xlabel('Genres')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The countplot indicates that 'Drama' is the most popular genre in the dataset, followed by 'Comedy' and 'Action.'

# %%
# 18. How does the movie rating vary by director's experience (number of movies directed)?
director_experience = df.groupby('director')['id'].count().reset_index()
director_experience.columns = ['director', 'num_movies']
movie_data_with_experience = pd.merge(filtered_data, director_experience, on='director', how='left')
plt.figure(figsize=(12, 6))
sns.scatterplot(x='num_movies', y='vote_average', data=movie_data_with_experience, hue='genres', palette='tab10')
plt.title('Rating vs. Director\'s Experience')
plt.xlabel('Number of Movies Directed by Director')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# - By this scatterplot comparing director experience to movie ratings reveals no clear trend, indicating that a director's experience does not consistently correlate with higher or lower movie ratings, and that ratings vary widely across genres.

# %%
df.corr()
# Out:
#                    index    budget        id  popularity   revenue   runtime  \
# index           1.000000 -0.770992  0.082707   -0.372255 -0.547246 -0.363512
# budget         -0.770992  1.000000 -0.039062    0.445551  0.741173  0.363574
# id              0.082707 -0.039062  1.000000    0.117441 -0.029608 -0.058912
# popularity     -0.372255  0.445551  0.117441    1.000000  0.587567  0.289795
# revenue        -0.547246  0.741173 -0.029608    0.587567  1.000000  0.379620
# runtime        -0.363512  0.363574 -0.058912    0.289795  0.379620  1.000000
# vote_average   -0.028606  0.063392 -0.132695    0.297738  0.247318  0.380913
# vote_count     -0.468143  0.597986  0.028322    0.715044  0.780843  0.442273
# release_ year  -0.158279  0.160992  0.485790    0.049236  0.017193 -0.086105
# release_month  -0.042802  0.021032 -0.025335    0.022511  0.040324  0.176199
# Profit         -0.443344  0.611997 -0.024679    0.575839  0.984511  0.352270
# ...

# %%
# 19.What does the correlation heatmap of the movie dataset reveal about the relationships between different numerical attributes? 

numerical_columns =df.select_dtypes(include=['int', 'float'])

# Create a correlation matrix
correlation_matrix = numerical_columns.corr()

# Set the size of the heatmap
plt.figure(figsize=(10, 8))

# Create the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)

# Set the title
plt.title('Correlation Heatmap of Movie Dataset')

# Display the heatmap
plt.show()

# %% [markdown]
# - Attributes like 'revenue' and 'budget' are positively correlated, indicating that movies with higher budgets tend to generate higher revenues.
# - There is a positive correlation between 'popularity' and 'vote_count,' showing that more popular movies tend to receive a higher number of votes.
# - A negative correlation is observed between 'vote_average' and 'runtime,' implying that longer movies do not necessarily receive higher ratings.
# - 'vote_average' and 'popularity' have a  weak positive correlation, indicating that a movie's popularity has a limited impact on its user rating.

# %%
# 20.displaying different movie trends in budget, revenue, popularity, 
# runtime, and user ratings in the movie dataset over time by using line plots

# Define a custom color palette for the line plots
custom_palette = ['royalblue', 'forestgreen', 'tomato', 'gold', 'purple']

# Create subplots
fig, axes = plt.subplots(5, 1, figsize=(12, 20))

# Plot 1: Budget Trends Over Time
sns.lineplot(x='release_ year', y='budget', data=df, ax=axes[0], color=custom_palette[0])
axes[0].set_title('Average Movie Budget Over Time')
axes[0].set_xlabel('Release Year')
axes[0].set_ylabel('Budget')

# Plot 2: Revenue Trends Over Time
sns.lineplot(x='release_ year', y='revenue', data=df, ax=axes[1], color=custom_palette[1])
axes[1].set_title('Average Movie Revenue Over Time')
axes[1].set_xlabel('Release Year')
axes[1].set_ylabel('Revenue')

# Plot 3: Popularity Trends Over Time
sns.lineplot(x='release_ year', y='popularity', data=df, ax=axes[2], color=custom_palette[2])
axes[2].set_title('Movie Popularity Over Time')
axes[2].set_xlabel('Release Year')
axes[2].set_ylabel('Popularity')

# Plot 4: Runtime Trends Over Time
sns.lineplot(x='release_ year', y='runtime', data=df, ax=axes[3], color=custom_palette[3])
axes[3].set_title('Average Movie Runtime Over Time')
axes[3].set_xlabel('Release Year')
axes[3].set_ylabel('Runtime (minutes)')

# Plot 5: User Rating Trends Over Time
sns.lineplot(x='release_ year', y='vote_average', data=df, ax=axes[4], color=custom_palette[4])
axes[4].set_title('User Ratings Over Time')
axes[4].set_xlabel('Release Year')
axes[4].set_ylabel('User Rating')

# Adjust subplot layout
plt.tight_layout()

# Show the combined plot
plt.show()

# %% [markdown]
# - By these plots ,
# 1) Budget Trends Over Time: The first plot shows the average movie budget over the years. It suggests that budgets have generally increased over time.
# 2) Revenue Trends Over Time: The second plot displays the average movie revenue over the years.
# 3) Popularity Trends Over Time: The third plot shows that movie popularity, as measured in the dataset, has experienced ups and downs over time.
# 4) Runtime Trends Over Time: The fourth plot presents the average movie runtime over the years.
# 5) User Rating Trends Over Time: The fifth plot displays some years showing higher average ratings than others.

# %%
# Most Frequent Taglines over decades

df['release_decade'] = (df['release_date'].dt.year // 10) * 10
top_taglines = df.groupby('release_decade')['tagline'].apply(lambda x: x.value_counts().idxmax())

plt.figure(figsize=(12, 6))
sns.countplot(x='release_decade', hue='tagline', data=df, palette='viridis')
plt.title('Most Frequent Taglines by Decade')
plt.xlabel('Release Decade')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Taglines', loc='upper right', labels=top_taglines)
plt.show()

# %%
# How does the average runtime vary across different original languages?

plt.figure(figsize=(12, 6))
language_runtime_matrix = df.pivot_table(index='original_language', columns='duration_category', values='runtime', aggfunc='mean')
sns.heatmap(language_runtime_matrix, cmap='YlOrRd', linewidths=0.5)
plt.title('Average Runtime by Original Language and Duration Category')
plt.xlabel('Duration Category')
plt.ylabel('Original Language')
plt.show()

# %%
# Who are the top 10 most frequently appearing cast members in the dataset?
plt.figure(figsize=(12, 6))
top_10_cast = df['cast'].str.split('|').explode().value_counts().head(7)
sns.barplot(x=top_10_cast.values, y=top_10_cast.index, palette='viridis')
plt.title('Top 10 Most Frequent Cast Members')
plt.xlabel('Frequency')
plt.ylabel('Cast Member')
plt.show()

# %%
# What is the distribution of movies produced by different countries?
plt.figure(figsize=(12, 6))
production_country_counts = df['production_countries'].str.split('|').explode().value_counts().head(5)
sns.barplot(x=production_country_counts.values, y=production_country_counts.index, palette='Set3')
plt.title('Distribution of Movies by Production Countries (Top 10)')
plt.xlabel('Number of Movies')
plt.ylabel('Production Country')
plt.show()

# %%
# Number of titles (primaryTitle) per year
df_titles = df.groupby('release_ year')['title'].count()
df_titles.plot.line(x='release_ year', title='Number of titles per year', figsize=(12,5))
# Out:
# <Axes: title={'center': 'Number of titles per year'}, xlabel='release_ year'>

# %%
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director',
#        'release_ year', 'release_month', 'Profit', 'release_decade',
#        'duration_category'],
#       dtype='object')

# %%
# Variation in Runtime of Movies (Histogram or Box Plot)
plt.figure(figsize=(10, 6))
sns.histplot(df['runtime'], bins=20, kde=True)
plt.title('Distribution of Movie Runtimes')
plt.xlabel('Runtime')
plt.ylabel('Frequency')
plt.show()

# %%
# Top 10 directors who produced most of movies in between 1940 -2016

df.director.value_counts()[:10].plot.pie(autopct='%1.1f%%',figsize=(7,7))
plt.title('TOP 10 DIRECTORS OF MOVIES',color='Red')
plt.legend()
plt.show()

# %%
#  Profit Variation among Production Companies (Bar Plot)
top_production_companies = df.groupby('production_companies')['Profit'].sum().sort_values(ascending=False)[:10]
plt.figure(figsize=(12, 6))
top_production_companies.plot(kind='bar', color='salmon')
plt.title('Profit Variation among Production Companies')
plt.xlabel('Production Companies')
plt.ylabel('Total Profit')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Which length movies most liked by the audiences according to their popularity?

df.groupby('runtime')['popularity'].mean().plot(figsize = (13,5),xticks=np.arange(0,300,50))
plt.title("Runtime Vs Popularity",fontsize = 14)
plt.xlabel('Runtime',fontsize = 13)
plt.ylabel('Average Popularity',fontsize = 13)
sns.set(rc={'figure.figsize':(10,5)})
sns.set_style("whitegrid")

# %% [markdown]
# - According to the plot we can say that movies in the range of 150-200 runtime are more popular than other runtime movies. Because it is boring to see the long duration movies.

# %% [markdown]
# ## Conclusion:
#
# * Most of the movies rating are in between 6 to 7.5.
# * In september we have highest trend in release of movies.
# * Genres tend to have higher budgets on average, while others have lower budgets, reflecting the diversity in budget allocation within the movie industry.
# * The 2000s and 2010s witnessed a significant rise in movie production, with the highest number of releases during those decades.
# * Action, Adventure, and Animation genres tend to have the highest budgets and in turn generate higher revenues.
# * Avatar is the highest-grossing movie over that time period.
# * Movies with runtime duration of 90-120 minutes were mostly watched by viwers.
# * Genres have experienced variations in production from year to year, with certain years witnessing higher production counts for specific genres.
# * movies with higher revenues tend to be more popular.
# * The violin plot provides a concise visual summary of how movie runtimes differ within different genres, showcasing the range and density of duration values.
# * 'Drama' is the most popular genre in the dataset, followed by 'Comedy' and 'Action.'
# * Movies with higher budgets tend to generate higher revenues.
# * Longer movies do not necessarily receive higher ratings.
# * A movie's popularity has a limited impact on its user rating.
# * Budget Trends Over Time: It shows that  budgets have generally increased over time.
# * Revenue Trends Over Time: It displays the average movie revenue over the years.
# * Popularity Trends Over Time: it shows that movie popularity, as measured in the dataset, has experienced ups and downs over time.
# * Runtime Trends Over Time: It presents the average movie runtime over the years.
# * User Rating Trends Over Time: It displays some years showing higher average ratings than others.
# * Jennifer Lawrence Josh Hutcherson Liam Hemsworth Woody Harrelson Elizabeth Banks are top most frequent cast members.
# * Walt disney pictures are most profitable production companies.
# * Steven Spielberg is top director who produced most of the movies.
# * Most of movie titles where increased in between years 2000s to 2010s.
# * US is top most movie production country.
